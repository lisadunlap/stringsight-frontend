# %%
import pandas as pd
import json

# %%
from litellm import completion

# Cost-optimized: Use reasoning_effort="none" for best pricing
resp = completion(
    model="gemini/gemini-2.5-pro",
    messages=[{"role": "user", "content": "What is the capital of France?"}],
)
resp.choices[0].message.content
# Out:
# 'The capital of France is **Paris**.'

# %%
resp.choices[0].message.content
# Out:
# 'The capital of France is **Paris**.'

# %%
from datasets import load_dataset

# Login using e.g. `huggingface-cli login` to access this dataset
ds = load_dataset("dynamic-lm/update-interrupt-benchmark", "Coding")
# Out:
# README.md: 0.00B [00:00, ?B/s]
# data_code.parquet:   0%|          | 0.00/369k [00:00<?, ?B/s]
# Generating test split:   0%|          | 0/341 [00:00<?, ? examples/s]

# %%
response
# Out:
# ModelResponse(id='chatcmpl-20bb52d9-54df-4589-a886-53141a4db2b6', created=1764128308, model='anthropic.claude-3-sonnet-20240229-v1:0', object='chat.completion', system_fingerprint=None, choices=[Choices(finish_reason='stop', index=0, message=Message(content="Hello! I'm doing well, thank you for asking. I'm Claude, an AI assistant created by Anthropic.", role='assistant', tool_calls=None, function_call=None, provider_specific_fields=None))], usage=Usage(completion_tokens=28, prompt_tokens=13, total_tokens=41, completion_tokens_details=None, prompt_tokens_details=PromptTokensDetailsWrapper(audio_tokens=None, cached_tokens=0, text_tokens=None, image_tokens=None), cache_creation_input_tokens=0, cache_read_input_tokens=0))

# %%
ds['test'].to_pandas().to_json("interrupt_benchmark.jsonl", orient="records", lines=True)

# %%
# results/instruct_grok_gpt_5-test/full_dataset.json
pd.read_json('results/koala/conversation.jsonl', lines=True).columns
# Out:
# Index(['question_id', 'prompt', 'model', 'model_response', 'score',
#        'predicted_text'],
#       dtype='object')
